# %% [markdown]
# pd.read_...(skiprows =1 ) -> Pula linha do df
#
# criar um df com dados -> Passa um dict em Dataframe(dict)
#
# df2 = Dataframe(dados,
#                 columns = ['coluna1','coluna2'],
#                 index = ['linha1', 'linha2'])
#
# Isso cria um df adicionando em columns os nomes da coluna, e em index a primeira coluna (Series) dela.
