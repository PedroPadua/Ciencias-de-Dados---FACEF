# %%
import pandas as pd

# %%
df_dados= pd.read_csv(r'C:\Users\Pedro\Desktop\Ciência de Dados - FACEF\Aula 3\dados\pacientes.csv', encoding='latin1')
df_dados_json = pd.read_json(r'C:\Users\Pedro\Desktop\Ciência de Dados - FACEF\Aula 3\dados\pacientes.json')
